# %%
import pandas as pd
from datetime import time
import numpy as np

path = "data_after_process/"
path_result="dados_finais/"

# %%
df_train1 = pd.read_csv(path+"test_15.csv")

# %%
df_train1.head()
# Out:
#             time_start  volume  direction  tollgate_id          time_window
# 0  2016-10-25 00:15:00       0          0            1  [00:15:00,00:35:00)
# 1  2016-10-25 00:35:00       0          0            1  [00:35:00,00:55:00)
# 2  2016-10-25 00:55:00       0          0            1  [00:55:00,01:15:00)
# 3  2016-10-25 01:15:00       0          0            1  [01:15:00,01:35:00)
# 4  2016-10-25 01:35:00       0          0            1  [01:35:00,01:55:00)

# %%
df_train1['time_start'] = pd.to_datetime(df_train1['time_start'], format = '%Y-%m-%d %H:%M:%S')

# %%
df_train1.head()
# Out:
#            time_start  volume  direction  tollgate_id          time_window
# 0 2016-10-25 00:15:00       0          0            1  [00:15:00,00:35:00)
# 1 2016-10-25 00:35:00       0          0            1  [00:35:00,00:55:00)
# 2 2016-10-25 00:55:00       0          0            1  [00:55:00,01:15:00)
# 3 2016-10-25 01:15:00       0          0            1  [01:15:00,01:35:00)
# 4 2016-10-25 01:35:00       0          0            1  [01:35:00,01:55:00)

# %%
df_train1['weekday'] = df_train1['time_start'].dt.dayofweek + 1

# %%
df_train1['t'] = df_train1['time_start'].dt.time

# %%
df_train1['weekend'] = df_train1['weekday'].apply(lambda x: 0 if x < 6 else 1)

# %%
def get_hour(t):
        return t.hour

# %%
df_train1['hour'] = df_train1['t'].apply(get_hour)

# %%
df_train1['date'] = df_train1['time_start'].dt.date

# %%
del df_train1['t']

# %%
df_train1.head()
# Out:
#            time_start  volume  direction  tollgate_id          time_window  \
# 0 2016-10-25 00:15:00       0          0            1  [00:15:00,00:35:00)
# 1 2016-10-25 00:35:00       0          0            1  [00:35:00,00:55:00)
# 2 2016-10-25 00:55:00       0          0            1  [00:55:00,01:15:00)
# 3 2016-10-25 01:15:00       0          0            1  [01:15:00,01:35:00)
# 4 2016-10-25 01:35:00       0          0            1  [01:35:00,01:55:00)
#
#    weekday  weekend  hour        date
# 0        2        0     0  2016-10-25
# 1        2        0     0  2016-10-25
# 2        2        0     0  2016-10-25
# 3        2        0     1  2016-10-25
# 4        2        0     1  2016-10-25

# %%
df_train1["volume_anterior"] = df_train1.groupby(['direction', 'tollgate_id'])["volume"].transform("shift")
df_train1["volume_anterior"] = df_train1.groupby(['direction', 'tollgate_id'])["volume_anterior"].fillna(method="ffill").fillna(0)

# %%
df_train1.head()
# Out:
#            time_start  volume  direction  tollgate_id          time_window  \
# 0 2016-10-25 00:10:00       0          0            1  [00:10:00,00:30:00)
# 1 2016-10-25 00:30:00       0          0            1  [00:30:00,00:50:00)
# 2 2016-10-25 00:50:00       0          0            1  [00:50:00,01:10:00)
# 3 2016-10-25 01:10:00       0          0            1  [01:10:00,01:30:00)
# 4 2016-10-25 01:30:00       0          0            1  [01:30:00,01:50:00)
#
#    weekday  weekend  hour        date  volume_anterior
# 0        2        0     0  2016-10-25              0.0
# 1        2        0     0  2016-10-25              0.0
# 2        2        0     0  2016-10-25              0.0
# 3        2        0     1  2016-10-25              0.0
# 4        2        0     1  2016-10-25              0.0

# %%
#Adicionando valor da janela de tempo (2x) anterior na janela de tempo atual
df_train1["volume_anterior_2"] = df_train1.groupby(['direction', 'tollgate_id'])["volume"].transform("shift", 2)
df_train1["volume_anterior_2"] =df_train1.groupby(['direction', 'tollgate_id'])["volume_anterior_2"].fillna(method="ffill").fillna(0)
df_train1.head()
# Out:
#            time_start  volume  direction  tollgate_id          time_window  \
# 0 2016-10-25 00:15:00       0          0            1  [00:15:00,00:35:00)
# 1 2016-10-25 00:35:00       0          0            1  [00:35:00,00:55:00)
# 2 2016-10-25 00:55:00       0          0            1  [00:55:00,01:15:00)
# 3 2016-10-25 01:15:00       0          0            1  [01:15:00,01:35:00)
# 4 2016-10-25 01:35:00       0          0            1  [01:35:00,01:55:00)
#
#    weekday  weekend  hour        date  volume_anterior  volume_anterior_2
# 0        2        0     0  2016-10-25              0.0                0.0
# 1        2        0     0  2016-10-25              0.0                0.0
# 2        2        0     0  2016-10-25              0.0                0.0
# 3        2        0     1  2016-10-25              0.0                0.0
# 4        2        0     1  2016-10-25              0.0                0.0

# %%
df_train1['media_volume'] = df_train1.groupby(['time_window', 'weekday', 'direction', 'tollgate_id'])["volume"].transform(np.mean)

# %%
df_train1.head()
# Out:
#            time_start  volume  direction  tollgate_id          time_window  \
# 0 2016-10-25 00:15:00       0          0            1  [00:15:00,00:35:00)
# 1 2016-10-25 00:35:00       0          0            1  [00:35:00,00:55:00)
# 2 2016-10-25 00:55:00       0          0            1  [00:55:00,01:15:00)
# 3 2016-10-25 01:15:00       0          0            1  [01:15:00,01:35:00)
# 4 2016-10-25 01:35:00       0          0            1  [01:35:00,01:55:00)
#
#    weekday  weekend  hour        date  volume_anterior  volume_anterior_2  \
# 0        2        0     0  2016-10-25              0.0                0.0
# 1        2        0     0  2016-10-25              0.0                0.0
# 2        2        0     0  2016-10-25              0.0                0.0
# 3        2        0     1  2016-10-25              0.0                0.0
# 4        2        0     1  2016-10-25              0.0                0.0
#
#    media_volume
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df_train1['desvio_padrao'] = df_train1.groupby(['time_window', 'weekday', 'direction', 'tollgate_id'])["volume"].transform(np.std)

df_train1['desvio_padrao'].fillna(df_train1.groupby(['time_window', 'weekday', 'direction', 'tollgate_id'])["volume"].transform(np.mean), inplace=True)

# %%
df_train1.head()
# Out:
#            time_start  volume  direction  tollgate_id          time_window  \
# 0 2016-10-25 00:15:00       0          0            1  [00:15:00,00:35:00)
# 1 2016-10-25 00:35:00       0          0            1  [00:35:00,00:55:00)
# 2 2016-10-25 00:55:00       0          0            1  [00:55:00,01:15:00)
# 3 2016-10-25 01:15:00       0          0            1  [01:15:00,01:35:00)
# 4 2016-10-25 01:35:00       0          0            1  [01:35:00,01:55:00)
#
#    weekday  weekend  hour        date  volume_anterior  volume_anterior_2  \
# 0        2        0     0  2016-10-25              0.0                0.0
# 1        2        0     0  2016-10-25              0.0                0.0
# 2        2        0     0  2016-10-25              0.0                0.0
# 3        2        0     1  2016-10-25              0.0                0.0
# 4        2        0     1  2016-10-25              0.0                0.0
#
#    media_volume  desvio_padrao
# 0             0            0.0
# 1             0            0.0
# 2             0            0.0
# 3             0            0.0
# 4             0            0.0

# %%
df_train1.to_csv('data_after_process_valores_anteriores/test15_valor_anterior.csv', index = False)
